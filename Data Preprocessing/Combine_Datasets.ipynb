# %% [markdown]
# ## **Combine Dataset**

# %%
import pandas as pd

# Store DF

stores = pd.read_csv('/content/drive/MyDrive/GUVI FINAL PROJRCT/stores_data_set.csv')


# Sales DF

sales  = pd.read_csv('/content/drive/MyDrive/GUVI FINAL PROJRCT/sales_data_set.csv')

# Features DF

features = pd.read_csv('/content/drive/MyDrive/GUVI FINAL PROJRCT/Features_data_set.csv')

# %% [markdown]
# ### **Combine sales And Feature Dataset**

# %%
sales_1 = sales.loc[:210785]

sales_2 = sales.loc[210786:]

# %%
sales_1
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 210781     22    28  23/04/2010       1004.62      False
# 210782     22    28  30/04/2010       1011.78      False
# 210783     22    28  07/05/2010        794.89      False
# 210784     22    28  14/05/2010        874.47      False
# 210785     22    28  21/05/2010        862.98      False
#
# [210786 rows x 5 columns]

# %%
sales_2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 210786     22    28  28/05/2010        816.01      False
# 210787     22    28  04/06/2010        677.21      False
# 210788     22    28  11/06/2010        617.77      False
# 210789     22    28  18/06/2010        613.89      False
# 210790     22    28  25/06/2010        563.25      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [210784 rows x 5 columns]

# %%
sales_1.columns,features.columns
# Out:
# (Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object'),
#  Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#         'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#         'IsHoliday'],
#        dtype='object'))

# %%
df_1 = pd.merge(sales_1,features,on=['Store','Date','IsHoliday'],how='left')

# %%
df_1
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  05/02/2010      24924.50      False        42.31
# 1           1     1  12/02/2010      46039.49       True        38.51
# 2           1     1  19/02/2010      41595.55      False        39.93
# 3           1     1  26/02/2010      19403.54      False        46.63
# 4           1     1  05/03/2010      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 210781     22    28  23/04/2010       1004.62      False        51.04
# 210782     22    28  30/04/2010       1011.78      False        50.96
# 210783     22    28  07/05/2010        794.89      False        63.81
# 210784     22    28  14/05/2010        874.47      False        50.99
# 210785     22    28  21/05/2010        862.98      False        59.99
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df_2 = pd.merge(sales_2,features,on=['Store','IsHoliday','Date'],how='left')

# %%
df_2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0          22    28  28/05/2010        816.01      False        65.64
# 1          22    28  04/06/2010        677.21      False        69.49
# 2          22    28  11/06/2010        617.77      False        65.01
# 3          22    28  18/06/2010        613.89      False        67.13
# 4          22    28  25/06/2010        563.25      False        74.37
# ...       ...   ...         ...           ...        ...          ...
# 210779     45    98  28/09/2012        508.37      False        64.88
# 210780     45    98  05/10/2012        628.10      False        64.89
# 210781     45    98  12/10/2012       1061.02      False        54.47
# 210782     45    98  19/10/2012        760.01      False        56.47
# 210783     45    98  26/10/2012       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df_1.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  05/02/2010      24924.50      False        42.31       2.572
# 1      1     1  12/02/2010      46039.49       True        38.51       2.548
# 2      1     1  19/02/2010      41595.55      False        39.93       2.514
# 3      1     1  26/02/2010      19403.54      False        46.63       2.561
# 4      1     1  05/03/2010      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# ...

# %%
df_2.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0     22    28  28/05/2010        816.01      False        65.64       2.906
# 1     22    28  04/06/2010        677.21      False        69.49       2.857
# 2     22    28  11/06/2010        617.77      False        65.01       2.830
# 3     22    28  18/06/2010        613.89      False        67.13       2.805
# 4     22    28  25/06/2010        563.25      False        74.37       2.810
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  136.148910
# 1        NaN        NaN        NaN        NaN        NaN  136.218168
# 2        NaN        NaN        NaN        NaN        NaN  136.287426
# 3        NaN        NaN        NaN        NaN        NaN  136.324339
# 4        NaN        NaN        NaN        NaN        NaN  136.348314
#
#    Unemployment
# 0         8.348
# 1         8.348
# 2         8.348
# 3         8.348
# ...

# %%
df = pd.concat([df_1,df_2],ignore_index=True)

# %%
df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  05/02/2010      24924.50      False        42.31
# 1           1     1  12/02/2010      46039.49       True        38.51
# 2           1     1  19/02/2010      41595.55      False        39.93
# 3           1     1  26/02/2010      19403.54      False        46.63
# 4           1     1  05/03/2010      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  28/09/2012        508.37      False        64.88
# 421566     45    98  05/10/2012        628.10      False        64.89
# 421567     45    98  12/10/2012       1061.02      False        54.47
# 421568     45    98  19/10/2012        760.01      False        56.47
# 421569     45    98  26/10/2012       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df_new = df.copy()

# %%
df_new['date'] = pd.to_datetime(df_new['Date'],format='%d/%m/%Y')

# %%
df_new.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date                    object
# Weekly_Sales           float64
# IsHoliday                 bool
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# date            datetime64[ns]
# dtype: object

# %% [markdown]
# ### **Non presented dates From 2012 to 2013 years**

# %%
missing_dates = features[~features['Date'].isin(df_new['Date'])].reset_index(drop=True)

# %%
missing_dates
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  02/11/2012        55.32       3.386    6766.44    5147.70
# 1         1  09/11/2012        61.24       3.314   11421.32    3370.89
# 2         1  16/11/2012        52.92       3.252    9696.28     292.10
# 3         1  23/11/2012        56.23       3.211     883.59       4.17
# 4         1  30/11/2012        52.34       3.207    2460.03        NaN
# ...     ...         ...          ...         ...        ...        ...
# 1750     45  28/06/2013        76.05       3.639    4842.29     975.03
# 1751     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 1752     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 1753     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 1754     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
missing_dates['date'] = pd.to_datetime(missing_dates['Date'],format='%d/%m/%Y')

# %%
df_new_1 = df_new[['Store', 'Dept']]

# %%
df_new_1 = df_new_1.drop_duplicates().reset_index(drop=True)

# %%
df_new_1
# Out:
#       Store  Dept
# 0         1     1
# 1         1     2
# 2         1     3
# 3         1     4
# 4         1     5
# ...     ...   ...
# 3326     45    94
# 3327     45    95
# 3328     45    96
# 3329     45    97
# 3330     45    98
#
# [3331 rows x 2 columns]

# %%
df_new_1.Store.nunique()
# Out:
# 45

# %%
df_new_1.Dept.nunique()
# Out:
# 81

# %%
df_new_2 = pd.merge(df_new_1,missing_dates,on=['Store'],how='outer')

# %%
df_new_2
# Out:
#         Store  Dept        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           1     1  02/11/2012        55.32       3.386    6766.44
# 1           1     1  09/11/2012        61.24       3.314   11421.32
# 2           1     1  16/11/2012        52.92       3.252    9696.28
# 3           1     1  23/11/2012        56.23       3.211     883.59
# 4           1     1  30/11/2012        52.34       3.207    2460.03
# ...       ...   ...         ...          ...         ...        ...
# 129904     45    98  28/06/2013        76.05       3.639    4842.29
# 129905     45    98  05/07/2013        77.50       3.614    9090.48
# 129906     45    98  12/07/2013        79.37       3.614    3789.94
# 129907     45    98  19/07/2013        82.84       3.737    2961.49
# 129908     45    98  26/07/2013        76.06       3.804     212.02
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# ...

# %%
df_new_2.drop('date',axis=1,inplace=True)

# %%
df.shape,df_new_2.shape
# Out:
# ((421570, 14), (129909, 13))

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Temperature',
#        'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
#        'MarkDown5', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df_new_2.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1',
#        'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI',
#        'Unemployment', 'IsHoliday'],
#       dtype='object')

# %%
csv = pd.concat([df,df_new_2],ignore_index=True)

csv.shape
# Out:
# (551479, 14)

# %%
csv
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  05/02/2010      24924.50      False        42.31
# 1           1     1  12/02/2010      46039.49       True        38.51
# 2           1     1  19/02/2010      41595.55      False        39.93
# 3           1     1  26/02/2010      19403.54      False        46.63
# 4           1     1  05/03/2010      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 551474     45    98  28/06/2013           NaN      False        76.05
# 551475     45    98  05/07/2013           NaN      False        77.50
# 551476     45    98  12/07/2013           NaN      False        79.37
# 551477     45    98  19/07/2013           NaN      False        82.84
# 551478     45    98  26/07/2013           NaN      False        76.06
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
csv['Date'] = pd.to_datetime(csv['Date'],format='%d/%m/%Y')

csv['Day'] = pd.to_datetime(csv['Date'],format='%d/%m/%Y').dt.day

csv['Month'] = pd.to_datetime(csv['Date'],format='%d/%m/%Y').dt.month

csv['Year'] = pd.to_datetime(csv['Date'],format='%d%m%/%Y').dt.year

# %%
csv
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     1 2010-02-12      46039.49       True        38.51
# 2           1     1 2010-02-19      41595.55      False        39.93
# 3           1     1 2010-02-26      19403.54      False        46.63
# 4           1     1 2010-03-05      21827.90      False        46.50
# ...       ...   ...        ...           ...        ...          ...
# 551474     45    98 2013-06-28           NaN      False        76.05
# 551475     45    98 2013-07-05           NaN      False        77.50
# 551476     45    98 2013-07-12           NaN      False        79.37
# 551477     45    98 2013-07-19           NaN      False        82.84
# 551478     45    98 2013-07-26           NaN      False        76.06
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %% [markdown]
# ### **Combine Final Csv and Store**

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
df = pd.merge(csv,stores,on=['Store'],how='left')

df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     1 2010-02-12      46039.49       True        38.51
# 2           1     1 2010-02-19      41595.55      False        39.93
# 3           1     1 2010-02-26      19403.54      False        46.63
# 4           1     1 2010-03-05      21827.90      False        46.50
# ...       ...   ...        ...           ...        ...          ...
# 551474     45    98 2013-06-28           NaN      False        76.05
# 551475     45    98 2013-07-05           NaN      False        77.50
# 551476     45    98 2013-07-12           NaN      False        79.37
# 551477     45    98 2013-07-19           NaN      False        82.84
# 551478     45    98 2013-07-26           NaN      False        76.06
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df['IsHoliday'] = df['IsHoliday'].map({False:0,True:1})

df['Type'] = df['Type'].map({'A':1,'B':2,'C':3})

# %%
df.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50          0        42.31       2.572
# 1      1     1 2010-02-12      46039.49          1        38.51       2.548
# 2      1     1 2010-02-19      41595.55          0        39.93       2.514
# 3      1     1 2010-02-26      19403.54          0        46.63       2.561
# 4      1     1 2010-03-05      21827.90          0        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment  Day  Month  Year  Type    Size
# ...

# %%
df = df.sort_values(by=['Date','Store']).reset_index(drop=True)  # Sort df if u want

# %%
df.to_csv('Combined_Datasets.csv',index=False)

# %% [markdown]
# ```
#                                                                                                         Finished
# ```
